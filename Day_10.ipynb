# %% [markdown]
# <a href="https://colab.research.google.com/github/Sim8n88/ml_projects/blob/main/Day_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
dane_hr = {
    'Lata_doswiadczenia': [1, 3, 5, 2, 8, 10, 4, 6, 7, 9],
    'Liczba_projektow': [2, 4, 5, 3, 10, 15, 6, 8, 9, 12],
    'Ocena_pracownika': [60, 75, 80, 70, 95, 99, 78, 85, 88, 92],
    'Pensja': [4000, 5500, 7000, 4800, 10000, 12500, 6200, 7800, 8500, 11000] # To nasz cel!
}
df_hr = pd.DataFrame(dane_hr)
X=df_hr.drop(columns=['Pensja'])
Y=df_hr['Pensja']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
print(X_train.shape)
print(X_test.shape)
# Out:
# (8, 3)
# (2, 3)
