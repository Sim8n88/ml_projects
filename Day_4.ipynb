# %% [markdown]
# <a href="https://colab.research.google.com/github/Sim8n88/ml_projects/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dane_sklepu={
    'Produkt':['laptop','telefon','tablet'],
    'Cena':[2555,1000,1900],
    'Magazyn':[1,2,3]
}
pd_dane_sklepu=pd.DataFrame(dane_sklepu)
print(pd_dane_sklepu.tail(2))
pd_dane_sklepu.info()
same_ceny=pd_dane_sklepu['Cena']
print(same_ceny)
dwie_kolumny=pd_dane_sklepu[['Produkt','Cena']]
print(dwie_kolumny)
pd_dane_sklepu['Wartosc_towaru']=pd_dane_sklepu['Cena']*pd_dane_sklepu['Magazyn']
print(pd_dane_sklepu)
df=pd_dane_sklepu.drop(columns=['Magazyn'])
print(df)
# Out:
#    Produkt  Cena  Magazyn
# 1  telefon  1000        2
# 2   tablet  1900        3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Produkt  3 non-null      object
#  1   Cena     3 non-null      int64
#  2   Magazyn  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes
# 0    2555
# 1    1000
# 2    1900
# Name: Cena, dtype: int64
#    Produkt  Cena
# 0   laptop  2555
# 1  telefon  1000
# 2   tablet  1900
#    Produkt  Cena  Magazyn  Wartosc_towaru
# 0   laptop  2555        1            2555
# 1  telefon  1000        2            2000
# 2   tablet  1900        3            5700
#    Produkt  Cena  Wartosc_towaru
# 0   laptop  2555            2555
# 1  telefon  1000            2000
# 2   tablet  1900            5700
